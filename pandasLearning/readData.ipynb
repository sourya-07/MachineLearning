# %% [markdown]
# Reading Data from Different Sources

# %%
import pandas as pd
from io import StringIO
Data = '{"employee_name": "James", "email": "james@gmail.com", "job_profile": [{"title1": "Team Lead", "title2": "Senior Developer"}]}'
df = pd.read_json(StringIO(Data))

# %%
df
# Out:
#   employee_name            email  \
# 0         James  james@gmail.com
#
#                                          job_profile
# 0  {'title1': 'Team Lead', 'title2': 'Senior Deve...

# %%
df.to_json()
# Out:
# '{"employee_name":{"0":"James"},"email":{"0":"james@gmail.com"},"job_profile":{"0":{"title1":"Team Lead","title2":"Senior Developer"}}}'

# %%
df.to_json(orient='index')
# Out:
# '{"0":{"employee_name":"James","email":"james@gmail.com","job_profile":{"title1":"Team Lead","title2":"Senior Developer"}}}'

# %%
df.to_json(orient='records')
# Out:
# '[{"employee_name":"James","email":"james@gmail.com","job_profile":{"title1":"Team Lead","title2":"Senior Developer"}}]'

# %%
df = pd.read_csv("annual-enterprise-survey.csv", header = None)

# %%
df.head()
# Out:
#       0                            1                     2  \
# 0  Year  Industry_aggregation_NZSIOC  Industry_code_NZSIOC
# 1  2024                      Level 1                 99999
# 2  2024                      Level 1                 99999
# 3  2024                      Level 1                 99999
# 4  2024                      Level 1                 99999
#
#                       3                   4              5  \
# 0  Industry_name_NZSIOC               Units  Variable_code
# 1        All industries  Dollars (millions)            H01
# 2        All industries  Dollars (millions)            H04
# 3        All industries  Dollars (millions)            H05
# 4        All industries  Dollars (millions)            H07
#
#                                                  6                      7  \
# 0                                    Variable_name      Variable_category
# 1                                     Total income  Financial performance
# ...
